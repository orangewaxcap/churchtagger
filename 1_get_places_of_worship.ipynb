# %% [markdown]
# # Finding coordinates of places of worship

# %% [markdown]
# The first thing we need to do is download the coordinates of potential church buildings from OpenStreetMap.

# %%
import requests
import json
import pandas as pd
import numpy as np

# %% [markdown]
# We make a query to the Overpass API using an arbitrary bounding box, which goes from Aldham in the west to Elmstead in the east, and Horkesley Heath in the north to Fingringhoe in the south.

# %%
request = """
[out:json][timeout:25][bbox:51.844,0.778,51.942, 1.015];
// gather results
(
  // query part for: “church”
  node["amenity"="place_of_worship"]["religion"="christian"]["building"!="church"];
way["amenity"="place_of_worship"]["religion"="christian"]["building"!="church"];
  relation["amenity"="place_of_worship"]["religion"="christian"]["building"!="church"];
);
// print results

out body;
>;
out skel qt;
"""

overpass_url = "http://overpass-api.de/api/interpreter"
response = requests.get(overpass_url, params={'data': request})

# %% [markdown]
# ## Checking what we've got to work with

# %% [markdown]
# We can see the bounded area in the image below. We get 591 entities back from OpenStreetMap. 548 of these are nodes that are either point descriptions of a place of worship, or constituent parts of one of 43 "ways": an OpenStreetMap term used to described features like roads or (as in this case) the outline of buildings.
#
# 50 of the returns have names, so these are probably specific places of worship. Only 24 returns have any ```building``` information: one gospel hall building, one converted residential building, and 22 counts of "yes, this is a building".
#
# ![Map of Colchester showing the points returned from the OpenStreetMap query in blue-ringed markers](writeup_files/OSM_bbox_view.png)

# %% [markdown]
# The code below creates a dataframe with what OpenStreetMap's API sent us and rummages through it in various ways.

# %%
df = pd.json_normalize(response.json()['elements'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 591 entries, 0 to 590
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   type                     591 non-null    object
#  1   id                       591 non-null    int64
#  2   lat                      548 non-null    float64
#  3   lon                      548 non-null    float64
#  4   tags.amenity             50 non-null     object
#  5   tags.denomination        43 non-null     object
#  6   tags.name                50 non-null     object
#  7   tags.religion            50 non-null     object
#  8   tags.source              6 non-null      object
#  9   tags.wikidata            24 non-null     object
#  10  tags.addr:city           11 non-null     object
#  11  tags.addr:housename      4 non-null      object
#  12  tags.addr:postcode       14 non-null     object
#  13  tags.addr:street         13 non-null     object
#  14  tags.website             2 non-null      object
#  15  nodes                    43 non-null     object
#  16  tags.building            24 non-null     object
#  17  tags.postal_code         1 non-null      object
#  18  tags.alt_name            2 non-null      object
#  19  tags.fhrs:id             1 non-null      object
#  20  tags.source:addr         1 non-null      object
#  21  tags.source:alt_name     1 non-null      object
#  22  tags.phone               2 non-null      object
#  23  tags.wheelchair          2 non-null      object
#  24  tags.toilets:wheelchair  1 non-null      object
#  25  tags.source:building     4 non-null      object
#  26  tags.addr:housenumber    4 non-null      object
#  27  tags.opening_hours       1 non-null      object
#  28  tags.layer               1 non-null      object
#  29  tags.level               1 non-null      object
# dtypes: float64(2), int64(1), object(27)
# memory usage: 138.6+ KB

# %%
df['tags.building'].value_counts()
# Out:
# yes            22
# gospel_hall     1
# residential     1
# Name: tags.building, dtype: int64

# %%
df['type'].value_counts()
# Out:
# node    548
# way      43
# Name: type, dtype: int64

# %%
df.sample(20)
# Out:
#      type          id        lat       lon      tags.amenity  \
# 222  node  1637154021  51.872380  0.871695               NaN
# 198  node  1617190931  51.889566  0.863678               NaN
# 566  node   725493684  51.926527  0.985571               NaN
# 209  node  1617190995  51.889561  0.863170               NaN
# 508  node  1638640939  51.859007  0.959159               NaN
# 578  node   725493712  51.926612  0.986016               NaN
# 71   node  1577445316  51.898208  0.785804               NaN
# 27    way   150838753        NaN       NaN  place_of_worship
# 55   node  2476897947  51.851480  0.829909               NaN
# 204  node  1617190983  51.889541  0.863320               NaN
# 398  node  1637900069  51.910865  0.892127               NaN
# 357  node  1618362546  51.886970  0.932796               NaN
# 268  node  1643651379  51.879801  0.910816               NaN
# 5    node  3312122647  51.858495  0.947205  place_of_worship
# 286  node  3982961224  51.886609  0.895315               NaN
# 434  node  1635835016  51.911215  0.928388               NaN
# 149  node  5907660438  51.859967  0.908030               NaN
# 191  node   546580667  51.889658  0.863660               NaN
# 513  node  1638871814  51.860633  0.960412               NaN
# 291  node  5036319130  51.887372  0.899316               NaN
#
#     tags.denomination               tags.name tags.religion tags.source  \
# 222               NaN                     NaN           NaN         NaN
# 198               NaN                     NaN           NaN         NaN
# 566               NaN                     NaN           NaN         NaN
# 209               NaN                     NaN           NaN         NaN
# 508               NaN                     NaN           NaN         NaN
# 578               NaN                     NaN           NaN         NaN
# 71                NaN                     NaN           NaN         NaN
# 27           anglican  St Barnabas, Old Heath     christian         NaN
# 55                NaN                     NaN           NaN         NaN
# 204               NaN                     NaN           NaN         NaN
# 398               NaN                     NaN           NaN         NaN
# 357               NaN                     NaN           NaN         NaN
# 268               NaN                     NaN           NaN         NaN
# 5    free_evangelical        Mariners' Chapel     christian         NaN
# 286               NaN                     NaN           NaN         NaN
# 434               NaN                     NaN           NaN         NaN
# 149               NaN                     NaN           NaN         NaN
# 191               NaN                     NaN           NaN         NaN
# 513               NaN                     NaN           NaN         NaN
# 291               NaN                     NaN           NaN         NaN
#
#     tags.wikidata  ... tags.source:addr tags.source:alt_name tags.phone  \
# 222           NaN  ...              NaN                  NaN        NaN
# 198           NaN  ...              NaN                  NaN        NaN
# 566           NaN  ...              NaN                  NaN        NaN
# 209           NaN  ...              NaN                  NaN        NaN
# 508           NaN  ...              NaN                  NaN        NaN
# 578           NaN  ...              NaN                  NaN        NaN
# 71            NaN  ...              NaN                  NaN        NaN
# 27     Q105083493  ...              NaN                  NaN        NaN
# 55            NaN  ...              NaN                  NaN        NaN
# 204           NaN  ...              NaN                  NaN        NaN
# 398           NaN  ...              NaN                  NaN        NaN
# 357           NaN  ...              NaN                  NaN        NaN
# 268           NaN  ...              NaN                  NaN        NaN
# 5             NaN  ...              NaN                  NaN        NaN
# 286           NaN  ...              NaN                  NaN        NaN
# 434           NaN  ...              NaN                  NaN        NaN
# 149           NaN  ...              NaN                  NaN        NaN
# 191           NaN  ...              NaN                  NaN        NaN
# 513           NaN  ...              NaN                  NaN        NaN
# 291           NaN  ...              NaN                  NaN        NaN
#
#     tags.wheelchair tags.toilets:wheelchair tags.source:building  \
# 222             NaN                     NaN                  NaN
# 198             NaN                     NaN                  NaN
# 566             NaN                     NaN                  NaN
# 209             NaN                     NaN                  NaN
# 508             NaN                     NaN                  NaN
# 578             NaN                     NaN                  NaN
# 71              NaN                     NaN                  NaN
# 27              NaN                     NaN                  NaN
# 55              NaN                     NaN                  NaN
# 204             NaN                     NaN                  NaN
# 398             NaN                     NaN                  NaN
# 357             NaN                     NaN                  NaN
# 268             NaN                     NaN                  NaN
# 5               NaN                     NaN                  NaN
# 286             NaN                     NaN                  NaN
# 434             NaN                     NaN                  NaN
# 149             NaN                     NaN                  NaN
# 191             NaN                     NaN                  NaN
# 513             NaN                     NaN                  NaN
# 291             NaN                     NaN                  NaN
#
#     tags.addr:housenumber tags.opening_hours tags.layer tags.level
# 222                   NaN                NaN        NaN        NaN
# 198                   NaN                NaN        NaN        NaN
# 566                   NaN                NaN        NaN        NaN
# 209                   NaN                NaN        NaN        NaN
# 508                   NaN                NaN        NaN        NaN
# 578                   NaN                NaN        NaN        NaN
# 71                    NaN                NaN        NaN        NaN
# 27                    NaN                NaN        NaN        NaN
# 55                    NaN                NaN        NaN        NaN
# 204                   NaN                NaN        NaN        NaN
# 398                   NaN                NaN        NaN        NaN
# 357                   NaN                NaN        NaN        NaN
# 268                   NaN                NaN        NaN        NaN
# 5                     NaN                NaN        NaN        NaN
# 286                   NaN                NaN        NaN        NaN
# 434                   NaN                NaN        NaN        NaN
# 149                   NaN                NaN        NaN        NaN
# 191                   NaN                NaN        NaN        NaN
# 513                   NaN                NaN        NaN        NaN
# 291                   NaN                NaN        NaN        NaN
#
# [20 rows x 30 columns]

# %% [markdown]
# ## Giving places defined by an OpenStreetMap ```way``` a single pair of coordinates

# %% [markdown]
# Most of the places of worship are defined as building outlines rather than a single point on the map. This is good! But it does mean that we'd end up making several requests to Google for each building, which isn't good for speed, cost or storage. First we create a separate dataframe of the coordinates of each node that is used to make up a ```way```.

# %%
nodes_from_ways = df[(df['type']=='node') & (df['tags.amenity']!="place_of_worship")].dropna(axis=1).set_index('id',drop=True)
nodes_from_ways.head()
# Out:
#             type        lat       lon
# id
# 2476897942  node  51.851449  0.829922
# 2476897943  node  51.851484  0.830257
# 2476897944  node  51.851488  0.829958
# 2476897945  node  51.851554  0.830227
# 2476897946  node  51.851508  0.829950

# %% [markdown]
# Now we can go through the nodes in a place of worship's ```way``` and convert those into coordinates. If we average them, we'll get a coordinate near the centre of the building. In theory we should take the projection system into account, but we are dealing with tiny differences here so let's not overcomplicate things.

# %%
def find_centre(nodes, nodes_df):
    lats = []
    lons = []
    for node in nodes:
        lats.append(nodes_df.loc[int(node),'lat'])
        lons.append(nodes_df.loc[int(node),'lon'])
    mean_lat = sum(lats) / len(lats)
    mean_lon = sum(lons) / len(lons)
    
    return mean_lat.round(6), mean_lon.round(6)

# %% [markdown]
# Give it a test...

# %%
find_centre([2476897942], nodes_from_ways)
# Out:
# (51.851449, 0.829922)

# %% [markdown]
# Perfect. We'll create a dataframe of all the places of worship defined by ```way```s...

# %%
centre_guesses = df[df['nodes'].notna()]['nodes'].apply(lambda x: find_centre(x, nodes_from_ways))
centres_df = pd.DataFrame(centre_guesses)
centres_df[['lat','lon']] = centres_df['nodes'].to_list()
centres_df.head()
# Out:
#                     nodes        lat       lon
# 7    (51.89002, 0.896746)  51.890020  0.896746
# 8   (51.883674, 0.817888)  51.883674  0.817888
# 9   (51.894388, 0.999748)  51.894388  0.999748
# 10  (51.926554, 0.985736)  51.926554  0.985736
# 11  (51.855057, 0.959371)  51.855057  0.959371

# %% [markdown]
# ...and then stick them on to the rest of the data.

# %%
full_df = df.join(centres_df, rsuffix='_guess')

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 591 entries, 0 to 590
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   type                     591 non-null    object
#  1   id                       591 non-null    int64
#  2   lat                      548 non-null    float64
#  3   lon                      548 non-null    float64
#  4   tags.amenity             50 non-null     object
#  5   tags.denomination        43 non-null     object
#  6   tags.name                50 non-null     object
#  7   tags.religion            50 non-null     object
#  8   tags.source              6 non-null      object
#  9   tags.wikidata            24 non-null     object
#  10  tags.addr:city           11 non-null     object
#  11  tags.addr:housename      4 non-null      object
#  12  tags.addr:postcode       14 non-null     object
#  13  tags.addr:street         13 non-null     object
#  14  tags.website             2 non-null      object
#  15  nodes                    43 non-null     object
#  16  tags.building            24 non-null     object
#  17  tags.postal_code         1 non-null      object
#  18  tags.alt_name            2 non-null      object
#  19  tags.fhrs:id             1 non-null      object
#  20  tags.source:addr         1 non-null      object
#  21  tags.source:alt_name     1 non-null      object
#  22  tags.phone               2 non-null      object
#  23  tags.wheelchair          2 non-null      object
#  24  tags.toilets:wheelchair  1 non-null      object
#  25  tags.source:building     4 non-null      object
#  26  tags.addr:housenumber    4 non-null      object
#  27  tags.opening_hours       1 non-null      object
#  28  tags.layer               1 non-null      object
#  29  tags.level               1 non-null      object
#  30  nodes_guess              43 non-null     object
#  31  lat_guess                43 non-null     float64
#  32  lon_guess                43 non-null     float64
# dtypes: float64(4), int64(1), object(28)
# memory usage: 152.5+ KB

# %% [markdown]
# We don't want to be faffing with two different pairs of coordinate columns, so here we smash them together and create a ```coords_imputed``` column to let us trace which ones have had the averaging process applied. We also drop anything that isn't a place of worship in and of itself – we don't want to keep all the individual nodes that constituted ```way```s – by checking the ```tags.amenity``` column.

# %%
full_df.apply(lambda row: row['lat'] if row['lat'] != np.nan else row['lat_guess'], axis=1)
places_of_worship = full_df.dropna(subset='tags.amenity').copy()

# %%
places_of_worship['lat'] = places_of_worship.apply(lambda row: row['lat_guess'] if np.isnan(row['lat']) else row['lat'], axis=1)
places_of_worship['lon'] = places_of_worship.apply(lambda row: row['lon_guess'] if np.isnan(row['lon']) else row['lon'], axis=1)
places_of_worship['coords_imputed'] = places_of_worship['nodes'].notna()

# %%
places_of_worship[['tags.name','tags.denomination','type','lat','lon','nodes','coords_imputed']].sample(20)
# Out:
#                                             tags.name      tags.denomination  \
# 24                             St Matthew, Colchester               anglican
# 35                      St Marys, Little Birch (ruin)                    NaN
# 30                    St Monica Roman Catholic Church               catholic
# 14                         St Lawrence, East Donyland               anglican
# 39  The Salvation Army Family Worship and Communit...         salvation_army
# 45                       Seventh Day Adventist Church  seventh_day_adventist
# 34                             Colchester Gospel Hall                 gospel
# 15                 St Michael and All Angels, Copford               anglican
# 8                               St. Albright's Church               anglican
# 42         Salvation Army Colchester Mount Zion Corps         salvation_army
# 12                          Ardleigh Methodist Church              methodist
# 22                           St Margarets, Berechurch               anglican
# 26                              St Anne's, Colchester               anglican
# 43                          Prettygate Baptist Church                    NaN
# 5                                    Mariners' Chapel       free_evangelical
# 9              St Anne & St Laurence, Elmstead Market               anglican
# 0                                  Mile End Methodist              methodist
# 20                              St Andrew, Greenstead               anglican
# 1                                  St. Helen's Chapel         greek_orthodox
# 47                             Orchard Baptist Church                baptist
#
#     type        lat       lon  \
# 24   way  51.896684  0.934167
# 35   way  51.851490  0.830044
# 30   way  51.859073  0.959094
# 14   way  51.855661  0.946258
# 39   way  51.886494  0.895378
# 45   way  51.895173  0.895006
# 34   way  51.882990  0.913232
# 15   way  51.869317  0.809385
# 8    way  51.883674  0.817888
# 42   way  51.905430  0.923309
# 12   way  51.925747  0.983996
# 22   way  51.863692  0.907415
# 26   way  51.893957  0.922369
# 43   way  51.879687  0.864506
# 5   node  51.858495  0.947205
# 9    way  51.894388  0.999748
# 0   node  51.915396  0.890335
# 20   way  51.886936  0.932766
# 1   node  51.891233  0.901604
# 47   way  51.859921  0.907909
#
#                                                 nodes  coords_imputed
# 24  [1635864731, 1635864728, 1635864729, 163586472...            True
# 35  [2476897945, 2476897946, 2476897944, 247689794...            True
# 30  [1638640938, 1638640940, 1638640941, 163864093...            True
# 14  [280846218, 1584765682, 1584765677, 1584765674...            True
# 39  [3982961224, 3982961221, 3982961204, 398296120...            True
# 45  [4999912445, 4999912446, 4999912447, 499991244...            True
# 34  [2006157589, 2006157583, 2006157585, 200615759...            True
# 15  [1588968353, 1588968246, 1588968359, 158896835...            True
# 8   [412182280, 412182283, 1613783473, 1613783464,...            True
# 42  [4933245776, 4933245775, 4933245774, 493324577...            True
# 12  [1521035520, 1521035517, 1521035543, 152103554...            True
# 22  [1619444449, 1619444451, 1619444446, 161944445...            True
# 26  [1637031975, 1637031959, 1637031958, 163703195...            True
# 43  [4999912036, 4999912037, 4999912038, 499991203...            True
# 5                                                 NaN           False
# 9   [699006279, 699006282, 1508853270, 1508853275,...            True
# 0                                                 NaN           False
# 20  [1618362613, 3789622715, 1618362546, 161836262...            True
# 1                                                 NaN           False
# 47  [5907660431, 5907660440, 5907660432, 590766043...            True

# %% [markdown]
# Looks good! All we need to do now is keep just the columns we need, then save those for further processing.

# %%
places_of_worship[['id',
                   'tags.name','tags.denomination','tags.building',
                   'lat','lon','coords_imputed']].sort_values(by=['lon']).reset_index(drop=True).to_csv('places_of_worship.csv', index=False)

# %% [markdown]
# ***
